# %%
import sys
from pathlib import Path

import pandas as pd

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.data_loader import download_market_data

# %%
portfolio_assets = [
    "AAPL", #Apple
    "JPM", #JPMorgan Chase
    "JNJ", #Johnson & Johnson
    "KO", #Coca-Cola
    "XOM", #Exxon Mobil
    "GLD", #Gold ETF
    "TLT" #Long-Term Treasury Bond ETF
]

benchmark = "SPY"

tickers = portfolio_assets + [benchmark]

tickers
# Out:
# ['AAPL', 'JPM', 'JNJ', 'KO', 'XOM', 'GLD', 'TLT', 'SPY']

# %%
from datetime import date

start_date = "2016-01-01"
end_date = date.today().strftime("%Y-%m-%d")

print(f"Start Date: {start_date}")
print(f"End Date: {end_date}")
# Out:
# Start Date: 2016-01-01
# End Date: 2026-07-21

# %%
market_data = download_market_data(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date
)

# %%
market_data.head()
# Out:
# Ticker             GLD                                                \
# Price             Open        High         Low       Close    Volume
# Date
# 2016-01-04  103.129997  103.669998  102.489998  102.889999   6440000
# 2016-01-05  103.129997  103.459999  102.930000  103.180000   3500300
# 2016-01-06  104.370003  104.800003  103.930000  104.669998   9316600
# 2016-01-07  105.830002  106.239998  105.190002  106.150002  11730400
# 2016-01-08  105.480003  105.800003  105.040001  105.680000   7678200
#
# Ticker           AAPL                                              ...  \
# Price            Open       High        Low      Close     Volume  ...
# Date                                                               ...
# 2016-01-04  23.092468  23.713608  22.955186  23.709106  270597600  ...
# 2016-01-05  23.799122  23.821627  23.047453  23.114967  223164000  ...
# 2016-01-06  22.631110  23.038453  22.475826  22.662617  273829600  ...
# 2016-01-07  22.208010  22.534333  21.701646  21.706146  324377600  ...
# 2016-01-08  22.178758  22.304786  21.775917  21.820927  283192000  ...
#
# Ticker             KO                                                   JNJ  \
# Price            Open       High        Low      Close    Volume       Open
# Date
# 2016-01-04  30.512734  30.628040  30.246091  30.555975  16084100  76.259769
# 2016-01-05  30.491106  30.721717  30.390211  30.664062  15781900  75.412515
# 2016-01-06  30.411837  30.635240  30.296532  30.498316  16245100  74.842685
# 2016-01-07  30.015484  30.346987  29.871351  29.993862  20563600  74.460284
# 2016-01-08  30.015474  30.354182  29.842515  29.914579  14645900  74.887687
#
# Ticker
# Price            High        Low      Close    Volume
# Date
# 2016-01-04  76.334746  74.565273  75.337547  12722800
# 2016-01-05  76.057323  75.405015  75.652443   6467200
# 2016-01-06  75.704929  74.677734  75.270058   7733800
# 2016-01-07  75.045109  74.137880  74.392807   9433100
# 2016-01-08  74.932677  73.365641  73.598076   9766700
#
# [5 rows x 40 columns]

# %%
market_data.columns
# Out:
# MultiIndex([( 'GLD',   'Open'),
#             ( 'GLD',   'High'),
#             ( 'GLD',    'Low'),
#             ( 'GLD',  'Close'),
#             ( 'GLD', 'Volume'),
#             ('AAPL',   'Open'),
#             ('AAPL',   'High'),
#             ('AAPL',    'Low'),
#             ('AAPL',  'Close'),
#             ('AAPL', 'Volume'),
#             ( 'XOM',   'Open'),
#             ( 'XOM',   'High'),
#             ( 'XOM',    'Low'),
#             ( 'XOM',  'Close'),
#             ( 'XOM', 'Volume'),
#             ( 'JPM',   'Open'),
#             ( 'JPM',   'High'),
#             ( 'JPM',    'Low'),
#             ( 'JPM',  'Close'),
#             ( 'JPM', 'Volume'),
#             ( 'SPY',   'Open'),
#             ( 'SPY',   'High'),
#             ( 'SPY',    'Low'),
#             ( 'SPY',  'Close'),
#             ( 'SPY', 'Volume'),
#             ( 'TLT',   'Open'),
#             ( 'TLT',   'High'),
#             ( 'TLT',    'Low'),
#             ( 'TLT',  'Close'),
#             ( 'TLT', 'Volume'),
#             (  'KO',   'Open'),
#             (  'KO',   'High'),
#             (  'KO',    'Low'),
#             (  'KO',  'Close'),
#             (  'KO', 'Volume'),
#             ( 'JNJ',   'Open'),
#             ( 'JNJ',   'High'),
#             ( 'JNJ',    'Low'),
#             ( 'JNJ',  'Close'),
#             ( 'JNJ', 'Volume')],
#            names=['Ticker', 'Price'])

# %%
market_data.columns.levels
# Out:
# FrozenList([['AAPL', 'GLD', 'JNJ', 'JPM', 'KO', 'SPY', 'TLT', 'XOM'], ['Close', 'High', 'Low', 'Open', 'Volume']])

# %%
market_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2650 entries, 2016-01-04 to 2026-07-20
# Data columns (total 40 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (GLD, Open)     2650 non-null   float64
#  1   (GLD, High)     2650 non-null   float64
#  2   (GLD, Low)      2650 non-null   float64
#  3   (GLD, Close)    2650 non-null   float64
#  4   (GLD, Volume)   2650 non-null   int64
#  5   (AAPL, Open)    2650 non-null   float64
#  6   (AAPL, High)    2650 non-null   float64
#  7   (AAPL, Low)     2650 non-null   float64
#  8   (AAPL, Close)   2650 non-null   float64
#  9   (AAPL, Volume)  2650 non-null   int64
#  10  (XOM, Open)     2650 non-null   float64
#  11  (XOM, High)     2650 non-null   float64
#  12  (XOM, Low)      2650 non-null   float64
#  13  (XOM, Close)    2650 non-null   float64
#  14  (XOM, Volume)   2650 non-null   int64
#  15  (JPM, Open)     2650 non-null   float64
#  16  (JPM, High)     2650 non-null   float64
#  17  (JPM, Low)      2650 non-null   float64
#  18  (JPM, Close)    2650 non-null   float64
#  19  (JPM, Volume)   2650 non-null   int64
#  20  (SPY, Open)     2650 non-null   float64
#  21  (SPY, High)     2650 non-null   float64
#  22  (SPY, Low)      2650 non-null   float64
#  23  (SPY, Close)    2650 non-null   float64
#  24  (SPY, Volume)   2650 non-null   int64
#  25  (TLT, Open)     2650 non-null   float64
#  26  (TLT, High)     2650 non-null   float64
#  27  (TLT, Low)      2650 non-null   float64
#  28  (TLT, Close)    2650 non-null   float64
#  29  (TLT, Volume)   2650 non-null   int64
#  30  (KO, Open)      2650 non-null   float64
#  31  (KO, High)      2650 non-null   float64
#  32  (KO, Low)       2650 non-null   float64
#  33  (KO, Close)     2650 non-null   float64
#  34  (KO, Volume)    2650 non-null   int64
#  35  (JNJ, Open)     2650 non-null   float64
#  36  (JNJ, High)     2650 non-null   float64
#  37  (JNJ, Low)      2650 non-null   float64
#  38  (JNJ, Close)    2650 non-null   float64
#  39  (JNJ, Volume)   2650 non-null   int64
# dtypes: float64(32), int64(8)
# memory usage: 848.8 KB

# %%
close_prices = market_data.xs("Close", level=1,axis=1)
close_prices.head()
# Out:
# Ticker             GLD       AAPL        XOM        JPM         SPY  \
# Date
# 2016-01-04  102.889999  23.709106  49.319633  48.184086  169.471542
# 2016-01-05  103.180000  23.114967  49.739845  48.267387  169.758148
# 2016-01-06  104.669998  22.662617  49.325985  47.570595  167.616806
# 2016-01-07  106.150002  21.706146  48.536461  45.646873  163.595398
# 2016-01-08  105.680000  21.820927  47.555927  44.624428  161.799728
#
# Ticker            TLT         KO        JNJ
# Date
# 2016-01-04  90.649796  30.555975  75.337547
# 2016-01-05  90.284042  30.664062  75.652443
# 2016-01-06  91.500664  30.498316  75.270058
# 2016-01-07  91.664879  29.993862  74.392807
# 2016-01-08  92.075386  29.914579  73.598076

# %%
close_prices.shape
# Out:
# (2650, 8)

# %%
close_prices.isnull().sum()
# Out:
# Ticker
# GLD     0
# AAPL    0
# XOM     0
# JPM     0
# SPY     0
# TLT     0
# KO      0
# JNJ     0
# dtype: int64

# %%
close_prices.describe()
# Out:
# Ticker          GLD         AAPL          XOM          JPM          SPY  \
# count   2650.000000  2650.000000  2650.000000  2650.000000  2650.000000
# mean     184.269989   122.453957    73.482299   134.681529   370.706474
# std       81.566656    80.050931    30.304721    74.531592   154.010488
# min      102.889999    20.565868    23.823561    40.193787   154.161636
# 25%      124.089998    42.637198    52.666669    84.725430   241.667702
# 50%      166.580002   126.893192    57.579912   112.111572   359.152466
# 75%      187.332497   180.504566   100.200949   150.458015   442.960594
# max      495.899994   333.739990   170.313995   346.910004   757.618225
#
# Ticker          TLT           KO          JNJ
# count   2650.000000  2650.000000  2650.000000
# mean     100.103919    48.246565   133.961352
# std       16.127754    13.324197    34.780434
# min       73.702675    29.820902    71.791084
# 25%       87.120811    35.964250   107.570074
# 50%       95.658562    46.542973   138.063545
# 75%      111.595402    56.839993   150.269833
# max      142.699600    84.919998   267.239990

# %%
from pathlib import Path

processed_path = project_root / "data" / "processed"
processed_path.mkdir(parents=True, exist_ok=True)

close_prices.to_csv(processed_path / "close_prices.csv")

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
processed_path
# Out:
# WindowsPath('c:/Users/Satvika Putcha/OneDrive/Dokumen/equity-risk-assessment-framework/data/processed')
